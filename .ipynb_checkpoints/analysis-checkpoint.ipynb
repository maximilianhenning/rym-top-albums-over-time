# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
df_top_albums = pd.read_csv("./output/top_albums_over_time.csv", sep = ";")
df_albums = pd.read_csv("./output/albums.csv", sep = ";")
df_genres = pd.read_csv("./output/genres.csv", sep = ";")

# %%
column_list = df_top_albums.columns.tolist()
albums_dict = {}
for column in column_list:
    if "album" in column:
        albums_dict[column] = df_top_albums[column].tolist()

# %%
genres_dict = {}
for key in albums_dict.keys():
    album_list = albums_dict[key]
    new_key = key.split("_")[0]
    genres_dict[new_key] = []
    for album in album_list:
        genre_arrays = df_albums.loc[df_albums["album"] == str(album)]["genres_top"].values
        for genres in genre_arrays:
            genres_dict[new_key].append(genres)
genres_dict
# Out:
# {'2001': ['psychedelic pop,pop rock',
#   'grunge,alternative rock',
#   'alternative rock,art rock',
#   'tbd',
#   'pop rock,rock',
#   'pop rock,psychedelic pop',
#   'new wave,punk rock',
#   'pop rock',
#   'hard rock',
#   'pop rock',
#   'tbd',
#   'acoustic rock,alternative rock',
#   'psychedelic pop,pop rock',
#   'pop rock',
#   'rock opera,art rock',
#   'pop rock',
#   'blues rock,psychedelic rock,acid rock',
#   'mod revival,new wave,power pop',
#   'punk rock',
#   'east coast hip hop,hardcore hip hop',
#   'alternative rock,third wave ska,ska punk',
#   'alterantive rock,alternative dance',
#   'heavy metal',
#   'tbd',
#   'folk rock,alternative rock',
#   'britpop',
#   'chamber pop,twee pop,indie pop',
#   'pop rock,singer/songwriter,blues rock',
#   'tbd',
#   'mod,beat music',
#   'alternative rock,pop rock',
#   'baroque pop',
#   'alternative rock,big music,pop rock',
#   'tbd',
#   'tbd',
#   'hard rock',
#   'alternative rock,pop rock',
#   'pop rock,singer/songwriter',
#   'folk pop,folk rock',
#   'east coast hip hop,mid-school hip hop'],
#  '2002': ['pop rock,psychedelic pop',
#   'psychedelic pop,pop rock',
#   'singer/songwriter,folk rock',
#   'roots rock',
#   'new wave,pop rock',
#   'punk rock',
#   'spiritual jazz',
#   'roots rock,folk rock,country rock',
#   'modal jazz,cool jazz',
#   'hard bop',
#   'blues rock,psychedelic rock,acid rock',
#   'pop rock',
#   'art rock,experimental rock',
#   'folk rock,singer/songwriter',
#   'blues rock,roots rock',
#   'blues rock',
#   'psychedelic pop,psychedelic rock,baroque pop,psychedelic folk',
#   'psychedelic rock,blues rock,acid rock',
#   'psychedelic rock',
#   'baggy',
#   'contemporary folk,singer/songwriter',
#   'alternative rock,indie rock',
#   'jazz fusion,modal jazz',
#   'singer/songwriter,chamber folk,contemporary folk',
#   'post-rock',
#   'hard rock',
#   'tbd',
#   'noise rock,alternative rock',
#   'experimental rock,art rock',
#   'punk rock',
#   'post-punk',
#   'psychedelic rock,blues rock,acid rock',
#   'folk rock,singer/songwriter,country rock',
#   'contemporary r&b,pop rock',
#   'singer/songwriter,pop rock',
#   'blues rock',
#   'industrial rock,industrial metal',
#   'tbd',
#   'progressive rock,hard rock',
#   'alternative rock,art rock'],
#  '2003': ['singer/songwriter,folk rock',
#   'contemporary folk,singer/songwriter',
#   'post-punk',
#   'avant-garde jazz',
#   'country rock,singer/songwriter,country',
#   'pop rock,psychedelic pop',
#   'psychedelic pop,pop rock',
#   'hard bop,cool jazz',
#   'baggy',
#   'spiritual jazz',
#   'folk rock,singer/songwriter',
#   'blues rock,psychedelic rock,acid rock',
#   'new wave,pop rock',
#   'post-punk',
#   'contemporary folk,singer/songwriter',
#   'roots rock,folk rock,country rock',
#   'british folk rock,contemporary folk',
#   'art rock,experimental rock',
#   'post-bop',
#   'modal jazz,cool jazz',
#   'alternative rock,indie rock',
#   'pop rock',
#   'punk rock,art punk',
#   'avant-garde jazz,third stream',
#   'singer/songwriter,chamber folk,contemporary folk',
#   'hard rock',
#   'psychedelic rock,blues rock,acid rock',
#   'folk rock,singer/songwriter,contemporary folk',
#   'canterbury scene,art rock',
#   'post-punk,experimental rock',
#   'punk rock',
#   'tbd',
#   'east coast hip hop,gangsta rap',
#   'singer/songwriter,experimental rock',
#   'jazz fusion,modal jazz',
#   'tbd',
#   'pop rock',
#   'singer/songwriter,contemporary folk',
#   'political hip hop,east coast hip hop,hardcore hip hop,conscious hip hop',
#   'punk rock'],
#  '2006': ['pop rock,psychedelic pop',
#   'folk rock,singer/songwriter',
#   'pop rock',
#   'singer/songwriter,folk rock',
#   'spiritual jazz',
#   'modal jazz,cool jazz',
#   'alternative rock,art rock',
#   'art rock,experimental rock',
#   'pop rock,rock',
#   'art rock,progressive rock',
#   'folk rock,singer/songwriter,contemporary folk',
#   'folk rock,singer/songwriter',
#   'avant-garde jazz,third stream',
#   'glam rock,pop rock',
#   'progressive rock,art rock',
#   'blues rock,psychedelic rock,acid rock',
#   'hard rock',
#   'hard rock',
#   'jazz fusion,modal jazz',
#   'new wave,punk rock',
#   'psychedelic rock,blues rock,acid rock',
#   'pop rock',
#   'indie folk,indie rock',
#   'art punk,art rock,post-punk',
#   'pop rock',
#   'alternative rock,indie rock',
#   'hard bop',
#   'jangle pop,indie pop',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'soul',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'psychedelic pop,pop rock',
#   'thrash metal',
#   'contemporary folk,singer/songwriter',
#   'psychedelic pop,baroque pop',
#   'blues rock',
#   'singer/songwriter,experimental rock',
#   'thrash metal',
#   'singer/songwriter,chamber folk',
#   'avant-garde jazz'],
#  '2009': ['pop rock,psychedelic pop',
#   'alternative rock,art rock',
#   'pop rock',
#   'art rock,experimental rock',
#   'art rock,progressive rock',
#   'folk rock,singer/songwriter',
#   'progressive rock,art rock',
#   'modal jazz,cool jazz',
#   'glam rock,pop rock',
#   'tbd',
#   'spiritual jazz',
#   'psychedelic pop,pop rock',
#   'avant-garde jazz,third stream',
#   'folk rock,singer/songwriter,contemporary folk',
#   'folk rock,singer/songwriter',
#   'hard rock',
#   'blues rock,psychedelic rock,acid rock',
#   'singer/songwriter,folk rock',
#   'progressive rock,art rock',
#   'new wave,punk rock',
#   'art punk,art rock,post-punk',
#   'folk rock,contemporary folk,singer/songwriter',
#   'alternative rock,indie rock',
#   'post-punk',
#   'contemporary folk,singer/songwriter',
#   'pop rock',
#   'psychedelic rock',
#   'jangle pop,indie pop',
#   'shoegaze,noise pop',
#   'psychedelic rock,blues rock,acid rock',
#   'art rock,experimental rock,electronic',
#   'folk rock,singer/songwriter,country rock',
#   'post-punk',
#   'heavy metal,hard rock',
#   'baroque pop',
#   'contemporary folk,singer/songwriter',
#   'pop rock',
#   'new wave,post-punk',
#   'hard rock',
#   'singer/songwriter,experimental rock'],
#  '2010': ['pop rock',
#   'pop rock,psychedelic pop',
#   'alternative rock,art rock',
#   'art rock,experimental rock',
#   'art rock,progressive rock',
#   'progressive rock,art rock',
#   'folk rock,singer/songwriter',
#   'modal jazz,cool jazz',
#   'glam rock,pop rock',
#   'psychedelic pop,pop rock',
#   'pop rock,rock',
#   'spiritual jazz',
#   'hard rock',
#   'progressive rock,art rock',
#   'avant-garde jazz,third stream',
#   'folk rock,singer/songwriter,contemporary folk',
#   'folk rock,singer/songwriter',
#   'blues rock,psychedelic rock,acid rock',
#   'singer/songwriter,folk rock',
#   'alternative rock,indie rock',
#   'post-punk',
#   'pop rock',
#   'art punk,art rock,post-punk',
#   'art rock,experimental rock,electronic',
#   'contemporary folk,singer/songwriter',
#   'new wave,punk rock',
#   'jangle pop,indie pop',
#   'psychedelic rock',
#   'shoegaze,noise pop',
#   'baroque pop',
#   'folk rock,contemporary folk,singer/songwriter',
#   'heavy metal,hard rock',
#   'post-punk',
#   'psychedelic rock,blues rock,acid rock',
#   'folk rock,singer/songwriter,country rock',
#   'contemporary folk,singer/songwriter',
#   'new wave,post-punk',
#   'singer/songwriter,experimental rock',
#   'pop rock',
#   'hard rock'],
#  '2011': ['alternative rock,art rock',
#   'pop rock,psychedelic pop',
#   'pop rock',
#   'art rock,experimental rock',
#   'art rock,progressive rock',
#   'progressive rock,art rock',
#   'folk rock,singer/songwriter',
#   'modal jazz,cool jazz',
#   'psychedelic pop,pop rock',
#   'glam rock,pop rock',
#   'spiritual jazz',
#   'progressive rock,art rock',
#   'hard rock',
#   'pop rock,rock',
#   'avant-garde jazz,third stream',
#   'art rock,experimental rock,electronic',
#   'folk rock,singer/songwriter',
#   'post-punk',
#   'blues rock,psychedelic rock,acid rock',
#   'alternative rock,indie rock',
#   'folk rock,singer/songwriter,contemporary folk',
#   'singer/songwriter,folk rock',
#   'pop rock',
#   'heavy metal,hard rock',
#   'new wave,punk rock',
#   'art punk,art rock,post-punk',
#   'contemporary folk,singer/songwriter',
#   'psychedelic rock',
#   'shoegaze,noise pop',
#   'jangle pop,indie pop',
#   'baroque pop',
#   'post-punk',
#   'folk rock,singer/songwriter,country rock',
#   'psychedelic rock,blues rock,acid rock',
#   'new wave,post-punk',
#   'contemporary folk,singer/songwriter',
#   'folk rock,contemporary folk,singer/songwriter',
#   'singer/songwriter,experimental rock',
#   'noise rock,alternative rock',
#   'progressive rock,art rock'],
#  '2012': ['alternative rock,art rock',
#   'art rock,progressive rock',
#   'pop rock,psychedelic pop',
#   'art rock,experimental rock',
#   'pop rock',
#   'progressive rock,art rock',
#   'psychedelic pop,pop rock',
#   'folk rock,singer/songwriter',
#   'art rock,experimental rock,electronic',
#   'hard rock',
#   'modal jazz,cool jazz',
#   'progressive rock,art rock',
#   'glam rock,pop rock',
#   'pop rock,rock',
#   'spiritual jazz',
#   'post-punk',
#   'heavy metal,hard rock',
#   'new wave,punk rock',
#   'shoegaze,noise pop',
#   'alternative rock,indie rock',
#   'pop rock',
#   'psychedelic rock',
#   'blues rock,psychedelic rock,acid rock',
#   'folk rock,singer/songwriter',
#   'art punk,art rock,post-punk',
#   'contemporary folk,singer/songwriter',
#   'avant-garde jazz,third stream',
#   'jangle pop,indie pop',
#   'post-punk',
#   'baroque pop',
#   'singer/songwriter,folk rock',
#   'folk rock,singer/songwriter,contemporary folk',
#   'new wave,post-punk',
#   'indie rock,chamber pop',
#   'folk rock,singer/songwriter,country rock',
#   'psychedelic rock,blues rock,acid rock',
#   'hard rock,blues rock',
#   'singer/songwriter,experimental rock',
#   'noise rock,alternative rock',
#   'progressive rock,art rock'],
#  '2013': ['alternative rock,art rock',
#   'art rock,progressive rock',
#   'art rock,experimental rock',
#   'progressive rock,art rock',
#   'pop rock',
#   'pop rock,psychedelic pop',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'hard rock',
#   'modal jazz,cool jazz',
#   'folk rock,singer/songwriter',
#   'shoegaze,noise pop',
#   'spiritual jazz',
#   'glam rock,pop rock',
#   'psychedelic pop,pop rock',
#   'alternative rock,indie rock',
#   'heavy metal,hard rock',
#   'baroque pop',
#   'post-punk',
#   'new wave,punk rock',
#   'pop rock,rock',
#   'psychedelic rock',
#   'jangle pop,indie pop',
#   'folk rock,singer/songwriter',
#   'blues rock,psychedelic rock,acid rock',
#   'contemporary folk,singer/songwriter',
#   'avant-garde jazz,third stream',
#   'art punk,art rock,post-punk',
#   'new wave,post-punk',
#   'singer/songwriter,folk rock',
#   'pop rock',
#   'folk rock,singer/songwriter,contemporary folk',
#   'post-punk',
#   'indie rock,chamber pop',
#   'progressive rock,art rock',
#   'indie folk,indie rock',
#   'noise rock,alternative rock',
#   'folk rock,singer/songwriter,country rock',
#   'post-rock',
#   'hard rock,blues rock'],
#  '2014': ['alternative rock,art rock',
#   'art rock,progressive rock',
#   'art rock,experimental rock',
#   'progressive rock,art rock',
#   'pop rock',
#   'pop rock,psychedelic pop',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'hard rock',
#   'modal jazz,cool jazz',
#   'shoegaze,noise pop',
#   'folk rock,singer/songwriter',
#   'glam rock,pop rock',
#   'heavy metal,hard rock',
#   'alternative rock,indie rock',
#   'baroque pop',
#   'spiritual jazz',
#   'psychedelic pop,pop rock',
#   'psychedelic rock',
#   'post-punk',
#   'new wave,punk rock',
#   'pop rock,rock',
#   'jangle pop,indie pop',
#   'contemporary folk,singer/songwriter',
#   'folk rock,singer/songwriter',
#   'new wave,post-punk',
#   'blues rock,psychedelic rock,acid rock',
#   'avant-garde jazz,third stream',
#   'art punk,art rock,post-punk',
#   'indie rock,chamber pop',
#   'progressive rock,art rock',
#   'singer/songwriter,folk rock',
#   'post-punk',
#   'indie folk,indie rock',
#   'pop rock',
#   'folk rock,singer/songwriter,contemporary folk',
#   'post-rock',
#   'noise rock,alternative rock',
#   'folk rock,singer/songwriter,country rock',
#   'hard rock,blues rock'],
#  '2015': ['alternative rock,art rock',
#   'art rock,progressive rock',
#   'art rock,experimental rock',
#   'progressive rock,art rock',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'pop rock',
#   'pop rock,psychedelic pop',
#   'hard rock',
#   'shoegaze,noise pop',
#   'modal jazz,cool jazz',
#   'folk rock,singer/songwriter',
#   'heavy metal,hard rock',
#   'alternative rock,indie rock',
#   'baroque pop',
#   'glam rock,pop rock',
#   'spiritual jazz',
#   'psychedelic pop,pop rock',
#   'psychedelic rock',
#   'post-punk',
#   'new wave,punk rock',
#   'jangle pop,indie pop',
#   'contemporary folk,singer/songwriter',
#   'pop rock,rock',
#   'indie folk,indie rock',
#   'folk rock,singer/songwriter',
#   'avant-garde jazz,third stream',
#   'blues rock,psychedelic rock,acid rock',
#   'indie rock,chamber pop',
#   'post-rock',
#   'art punk,art rock,post-punk',
#   'progressive rock,art rock',
#   'new wave,post-punk',
#   'post-punk',
#   'pop rock',
#   'noise rock,alternative rock',
#   'singer/songwriter,folk rock',
#   'grunge,alternative rock',
#   'hard rock,blues rock',
#   'thrash metal'],
#  '2016': ['alternative rock,art rock',
#   'art rock,progressive rock',
#   'art rock,experimental rock',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'progressive rock,art rock',
#   'pop rock',
#   'shoegaze,noise pop',
#   'pop rock,psychedelic pop',
#   'hard rock',
#   'modal jazz,cool jazz',
#   'baroque pop',
#   'glam rock,pop rock',
#   'heavy metal,hard rock',
#   'folk rock,singer/songwriter',
#   'alternative rock,indie rock',
#   'spiritual jazz',
#   'psychedelic pop,pop rock',
#   'psychedelic rock',
#   'post-punk',
#   'contemporary folk,singer/songwriter',
#   'jangle pop,indie pop',
#   'indie folk,indie rock',
#   'new wave,punk rock',
#   'post-rock',
#   'art punk,art rock,post-punk',
#   'pop rock,rock',
#   'new wave,post-punk',
#   'avant-garde jazz,third stream',
#   'indie rock,chamber pop',
#   'progressive rock,art rock',
#   'folk rock,singer/songwriter',
#   'blues rock,psychedelic rock,acid rock',
#   'grunge,alternative rock',
#   'post-punk',
#   'noise rock,alternative rock',
#   'art rock,ambient',
#   'singer/songwriter,folk rock',
#   'tbd',
#   'progressive rock,art rock'],
#  '2017': ['alternative rock,art rock',
#   'art rock,progressive rock',
#   'art rock,experimental rock',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'progressive rock,art rock',
#   'shoegaze,noise pop',
#   'pop rock',
#   'pop rock,psychedelic pop',
#   'hard rock',
#   'modal jazz,cool jazz',
#   'baroque pop',
#   'glam rock,pop rock',
#   'heavy metal,hard rock',
#   'alternative rock,indie rock',
#   'spiritual jazz',
#   'folk rock,singer/songwriter',
#   'indie folk,indie rock',
#   'post-punk',
#   'psychedelic rock',
#   'contemporary folk,singer/songwriter',
#   'psychedelic pop,pop rock',
#   'post-rock',
#   'jangle pop,indie pop',
#   'new wave,post-punk',
#   'art punk,art rock,post-punk',
#   'progressive rock,art rock',
#   'indie rock,chamber pop',
#   'pop rock,rock',
#   'avant-garde jazz,third stream',
#   'new wave,punk rock',
#   'art rock,ambient',
#   'art rock,alternative rock',
#   'folk rock,singer/songwriter',
#   'grunge,alternative rock',
#   'blues rock,psychedelic rock,acid rock',
#   'tbd',
#   'post-punk',
#   'noise rock,alternative rock',
#   'progressive rock,art rock'],
#  '2018': ['alternative rock,art rock',
#   'art rock,progressive rock',
#   'art rock,experimental rock,electronic',
#   'art rock,experimental rock',
#   'progressive rock,art rock',
#   'progressive rock,art rock',
#   'shoegaze,noise pop',
#   'baroque pop',
#   'pop rock',
#   'pop rock,psychedelic pop',
#   'modal jazz,cool jazz',
#   'hard rock',
#   'heavy metal,hard rock',
#   'glam rock,pop rock',
#   'indie folk,indie rock',
#   'art rock,alternative rock',
#   'post-rock',
#   'alternative rock,indie rock',
#   'spiritual jazz',
#   'post-punk',
#   'new wave,post-punk',
#   'contemporary folk,singer/songwriter',
#   'psychedelic rock',
#   'jangle pop,indie pop',
#   'folk rock,singer/songwriter',
#   'progressive rock,art rock',
#   'psychedelic pop,pop rock',
#   'indie rock,chamber pop',
#   'conscious hip hop,west coast hip hop,jazz rap',
#   'art rock,ambient',
#   'grunge,alternative rock',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'pop rap,hip hop',
#   'art punk,art rock,post-punk',
#   'avant-garde jazz,third stream',
#   'west coast hip hop,conscious hip hop',
#   'progressive rock,art rock',
#   'post-punk',
#   'pop rock,rock'],
#  '2020': ['alternative rock,art rock',
#   'progressive rock,art rock',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'shoegaze,noise pop',
#   'art rock,experimental rock',
#   'pop rock',
#   'glam rock,pop rock',
#   'avant-garde jazz,third stream',
#   'art rock,progressive rock',
#   'conscious hip hop,west coast hip hop,jazz rap',
#   'pop rock,psychedelic pop',
#   'new wave,post-punk',
#   'spiritual jazz',
#   'heavy metal,hard rock',
#   'modal jazz,cool jazz',
#   'art rock,alternative rock',
#   'baroque pop',
#   'west coast hip hop,conscious hip hop',
#   'abstract hip hop',
#   'indie folk,indie rock',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'post-rock',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'psychedelic pop,pop rock',
#   'progressive rock,art rock',
#   'contemporary folk,singer/songwriter',
#   'folk rock,singer/songwriter',
#   'post-rock,post-hardcore,math rock',
#   'jangle pop,indie pop',
#   'post-punk',
#   'pop rock,rock',
#   'alternative rock,indie rock',
#   'gothic rock,post-punk',
#   'jazz fusion,modal jazz',
#   'progressive rock,art rock',
#   'hard rock',
#   'pop rap,hip hop',
#   'art punk,art rock,post-punk',
#   'folk rock,singer/songwriter'],
#  '2021': ['alternative rock,art rock',
#   'progressive rock,art rock',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'shoegaze,noise pop',
#   'conscious hip hop,west coast hip hop,jazz rap',
#   'art rock,progressive rock',
#   'pop rock',
#   'art rock,experimental rock',
#   'glam rock,pop rock',
#   'pop rock,psychedelic pop',
#   'avant-garde jazz,third stream',
#   'new wave,post-punk',
#   'abstract hip hop',
#   'spiritual jazz',
#   'art rock,alternative rock',
#   'dream pop,neo-psychedelia',
#   'west coast hip hop,conscious hip hop',
#   'heavy metal,hard rock',
#   'modal jazz,cool jazz',
#   'baroque pop',
#   'indie folk,indie rock',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'post-rock',
#   'psychedelic pop,pop rock',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'progressive rock,art rock',
#   'contemporary folk,singer/songwriter',
#   'post-rock,post-hardcore,math rock',
#   'pop rock,rock',
#   'post-punk',
#   'gothic rock,post-punk',
#   'jangle pop,indie pop',
#   'folk rock,singer/songwriter',
#   'pop rap,hip hop',
#   'progressive rock,art rock',
#   'alternative rock,indie rock',
#   'hard rock',
#   'jazz fusion,modal jazz',
#   'art rock,ambient'],
#  '2023': ['conscious hip hop,west coast hip hop,jazz rap',
#   'alternative rock,art rock',
#   'progressive rock,art rock',
#   'progressive rock,art rock',
#   'art rock,experimental rock,electronic',
#   'abstract hip hop',
#   'shoegaze,noise pop',
#   'art rock,alternative rock',
#   'art rock,progressive rock',
#   'west coast hip hop,conscious hip hop',
#   'pop rock',
#   'glam rock,pop rock',
#   'new wave,post-punk',
#   'avant-garde jazz,third stream',
#   'art rock,experimental rock',
#   'pop rock,psychedelic pop',
#   'spiritual jazz',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'heavy metal,hard rock',
#   'post-rock',
#   'modal jazz,cool jazz',
#   'baroque pop',
#   'east coast hip hop,boom bap,hardcore hip hop',
#   'gothic rock,post-punk',
#   'progressive rock,art rock',
#   'post-rock,post-hardcore,math rock',
#   'indie folk,indie rock',
#   'pop rap,hip hop',
#   'progressive rock,art rock',
#   'contemporary folk,singer/songwriter',
#   'art pop,electronic',
#   'psychedelic pop,pop rock',
#   'dream pop,neo-psychedelia,progressive pop',
#   'post-punk',
#   'jazz fusion,modal jazz',
#   'jangle pop,indie pop',
#   'pop rock,rock',
#   'trip hop',
#   'art pop,progressive pop',
#   'soul']}

# %%
genre_percentage_dict = {}
for key in genres_dict.keys():
    genre_lists = genres_dict[key]
    genre_percentage_dict[key] = {}
    albums_total = len(genre_lists)
    for genres in genre_lists:
        genre_list = genres.split(",")
        genres_album_split = len(genre_list)
        for genre in genre_list:
            genre_album_percentage = 1 / genres_album_split
            genre_percentage = genre_album_percentage / albums_total
            if genre in genre_percentage_dict[key]:
                genre_percentage_dict[key][genre] += genre_percentage
            else:
                genre_percentage_dict[key][genre] = genre_percentage
df_genre_percentage = pd.DataFrame.from_dict(genre_percentage_dict)
df_genre_percentage
# Out:
#                       2001     2002    2003      2006      2009      2010  \
# psychedelic pop   0.037500  0.03125  0.0250  0.037500  0.025000  0.025000
# pop rock          0.204167  0.08750  0.0875  0.125000  0.112500  0.125000
# grunge            0.012500      NaN     NaN       NaN       NaN       NaN
# alternative rock  0.091667  0.03750  0.0125  0.025000  0.025000  0.025000
# art rock          0.025000  0.03750  0.0250  0.058333  0.079167  0.079167
# ...                    ...      ...     ...       ...       ...       ...
# dream pop              NaN      NaN     NaN       NaN       NaN       NaN
# neo-psychedelia        NaN      NaN     NaN       NaN       NaN       NaN
# art pop                NaN      NaN     NaN       NaN       NaN       NaN
# progressive pop        NaN      NaN     NaN       NaN       NaN       NaN
# trip hop               NaN      NaN     NaN       NaN       NaN       NaN
#
#                       2011      2012      2013      2014      2015      2016  \
# psychedelic pop   0.025000  0.025000  0.025000  0.025000  0.025000  0.025000
# pop rock          0.100000  0.100000  0.100000  0.100000  0.100000  0.075000
# grunge                 NaN       NaN       NaN       NaN  0.012500  0.012500
# alternative rock  0.037500  0.037500  0.037500  0.037500  0.050000  0.050000
# art rock          0.091667  0.091667  0.091667  0.091667  0.091667  0.116667
# ...                    ...       ...       ...       ...       ...       ...
# dream pop              NaN       NaN       NaN       NaN       NaN       NaN
# neo-psychedelia        NaN       NaN       NaN       NaN       NaN       NaN
# art pop                NaN       NaN       NaN       NaN       NaN       NaN
# progressive pop        NaN       NaN       NaN       NaN       NaN       NaN
# trip hop               NaN       NaN       NaN       NaN       NaN       NaN
#
#                       2017      2018      2020      2021      2023
# psychedelic pop   0.025000  0.025000  0.025000  0.025000  0.025000
# pop rock          0.075000  0.075000  0.075000  0.075000  0.075000
# grunge            0.012500  0.012500       NaN       NaN       NaN
# alternative rock  0.062500  0.050000  0.037500  0.037500  0.025000
# art rock          0.129167  0.129167  0.116667  0.120833  0.108333
# ...                    ...       ...       ...       ...       ...
# dream pop              NaN       NaN       NaN  0.012500  0.008333
# neo-psychedelia        NaN       NaN       NaN  0.012500  0.008333
# art pop                NaN       NaN       NaN       NaN  0.025000
# progressive pop        NaN       NaN       NaN       NaN  0.020833
# trip hop               NaN       NaN       NaN       NaN  0.025000
#
# [89 rows x 17 columns]

# %%
genre_top_parents_dict = {}
for x in df_genres.index:
    genre = df_genres.iloc[x]["genre"]
    genre_parents = df_genres.loc[x, ["genre", "parent1", "parent2", "parent3"]].values.flatten().tolist()
    if str(genre_parents[-1]) == "nan":
        if str(genre_parents[-2]) == "nan":
            if str(genre_parents[-3]) == "nan":
                top_parent = genre_parents[-4]
            else:
                top_parent = genre_parents[-3]
        else:
            top_parent = genre_parents[-2]
    else:
        top_parent = genre_parents[-1]
    genre_top_parents_dict[genre] = top_parent
genre_top_parents_dict
# Out:
# {'power pop': 'pop',
#  'psychedelic folk': 'folk',
#  'psychedelic rock': 'rock',
#  'canterbury scene': 'rock',
#  'dance-punk': 'rock',
#  'jazz rap': 'hip hop',
#  'soul': 'r&b',
#  'avant-prog': 'rock',
#  'heavy metal': 'metal',
#  'country': 'northern american music',
#  'art pop': 'pop',
#  'post-rock': 'rock',
#  'west coast hip hop': 'hip hop',
#  'industrial rock': 'industrial music',
#  'chamber jazz': 'jazz',
#  'blue-eyed soul': 'pop',
#  'synthpop': 'pop',
#  'experimental big band': 'jazz',
#  'microsound': 'experimental',
#  'folk pop': 'pop',
#  'free improvisation': 'experimental',
#  'flamenco jazz': 'jazz',
#  'art rock': 'rock',
#  'ambient pop': 'pop',
#  '2 tone': 'ska',
#  'mbaqanga': 'marabi',
#  'free jazz': 'jazz',
#  'poetry': 'spoken word',
#  'freakbeat': 'rock',
#  'industrial metal': 'metal',
#  'reggae': 'jamaican music',
#  'minneapolis sound': 'r&b',
#  'chamber folk': 'folk',
#  'funk': 'r&b',
#  'sunshine pop': 'pop',
#  'heartland rock': 'rock',
#  'thrash metal': 'metal',
#  'plunderphonics': 'experimental',
#  'synth funk': 'r&b',
#  'british folk rock': 'rock',
#  'rock opera': 'rock',
#  'chamber pop': 'pop',
#  'electric blues': 'blues',
#  'shoegaze': 'rock',
#  'dark cabaret': 'rock',
#  'krautrock': 'rock',
#  'merseybeat': 'pop',
#  'progressive rock': 'rock',
#  'ska': 'ska',
#  'noise rock': 'rock',
#  'third stream': 'jazz',
#  'alterantive rock': 'rock',
#  'americana': 'northern american music',
#  'post-punk revival': 'rock',
#  'roots rock': 'rock',
#  'space rock': 'rock',
#  'acoustic rock': 'rock',
#  'hardcore hip hop': 'hip hop',
#  'hip hop': 'hip hop',
#  'twee pop': 'pop',
#  'folk baroque': 'folk',
#  'east coast hip hop': 'hip hop',
#  'indie folk': 'folk',
#  'celtic folk music': 'european folk music',
#  'conscious hip hop': 'hip hop',
#  'psychedelic pop': 'pop',
#  'grunge': 'rock',
#  'alternative dance': 'dance',
#  'field recordings': 'field recordings',
#  'progressive pop': 'pop',
#  'big music': 'pop',
#  'modal jazz': 'jazz',
#  'proto-punk': 'rock',
#  'neo-psychedelia': 'psychedelia',
#  'coldwave': 'rock',
#  'pop rap': 'hip hop',
#  'symphonic prog': 'rock',
#  'tribal ambient': 'ambient',
#  'brass band': 'european music',
#  'drone': 'experimental',
#  'folk rock': 'rock',
#  'afrobeat': 'west african music',
#  'electronic': 'electronic',
#  'rythm & blues': 'r&b',
#  'country rock': 'northern american music',
#  'pop rock': 'pop',
#  'new wave': 'rock',
#  'mutant disco': 'disco',
#  'blues rock': 'rock',
#  'pop punk': 'rock',
#  'boogie rock': 'rock',
#  'death metal': 'metal',
#  'indie rock': 'rock',
#  'singer/songwriter': 'singer/songwriter',
#  'punk rock': 'rock',
#  'boom bap': 'hip hop',
#  'spiritual jazz': 'jazz',
#  'beat music': 'pop',
#  'glam rock': 'rock',
#  'contemporary r&b': 'r&b',
#  'acid jazz': 'r&b',
#  'mod revival': 'rock',
#  'hard bop': 'jazz',
#  'experimental rock': 'rock',
#  'jazz-rock': 'rock',
#  'spoken word': 'spoken word',
#  'mod': 'rock',
#  'rap rock': 'rock',
#  'beat poetry': 'spoken word',
#  'electro-industrial': 'electronic',
#  'noise pop': 'rock',
#  'hard rock': 'rock',
#  'dream pop': 'rock',
#  'lo-fi / slacker rock': 'rock',
#  'britpop': 'rock',
#  'abstract hip hop': 'hip hop',
#  'soukous': 'central african music',
#  'neo-soul': 'r&b',
#  'turntablism': 'hip hop',
#  'third wave ska': 'ska',
#  'dub': 'jamaican music',
#  'cool jazz': 'jazz',
#  'british rythm & blues': 'rock',
#  'acid rock': 'rock',
#  'glitch pop': 'indietronica',
#  'avant-garde jazz': 'jazz',
#  'post-bop': 'jazz',
#  'art punk': 'punk',
#  'surf rock': 'surf music',
#  'isicathamiya': 'southern african music',
#  'garage rock': 'rock',
#  'zydeco': 'louisiana music',
#  'trip hop': 'downtempo',
#  'gangsta rap': 'hip hop',
#  'ska punk': 'rock',
#  'pop soul': 'r&b',
#  'slowcore': 'rock',
#  'experimental hip hop': 'hip hop',
#  'symphonic rock': 'rock',
#  'baroque pop': 'pop',
#  'gothic rock': 'rock',
#  'jangle pop': 'rock',
#  'ambient': 'ambient',
#  'rockabilly': 'rock & toll',
#  'drum and bass': 'electronic dance music',
#  'political hip hop': 'hip hop',
#  'post-hardcore': 'hardcore [punk]',
#  'mid-school hip hop': 'hip hop',
#  'indie pop': 'pop',
#  'traditional doom metal': 'doom metal',
#  'psychedelic soul': 'r&b',
#  'contemporary folk': 'folk',
#  'progressive metal': 'metal',
#  'film soundtrack': 'soundtrack',
#  'rock': 'rock',
#  'alternative rock': 'rock',
#  'post-punk': 'rock',
#  'jazz fusion': 'jazz',
#  'math rock': 'rock',
#  'smooth soul': 'r&b',
#  'glam metal': 'rock',
#  'instrumental hip hop': 'hip hop',
#  'chamber music': 'western classical music',
#  'mbube': 'southern african music',
#  'baggy': 'rock',
#  'piano rock': 'pop',
#  'genre': 'tbd',
#  'post-industrial': 'industrial music'}

# %%
top_genres_dict = {}
for key in genres_dict.keys():
    genre_lists = genres_dict[key]
    genre_percentage_dict[key] = {}
    albums_total = len(genre_lists)
    for genres in genre_lists:
        genre_list = genres.split(",")
        genres_album_split = len(genre_list)
        for genre in genre_list:
            if genre != "tbd":
                genre = genre_top_parents_dict[genre]
                genre_album_percentage = 1 / genres_album_split
                genre_percentage = genre_album_percentage / albums_total
                if genre in genre_percentage_dict[key]:
                    genre_percentage_dict[key][genre] += genre_percentage
                else:
                    genre_percentage_dict[key][genre] = genre_percentage
df_top_genre_percentage = pd.DataFrame.from_dict(genre_percentage_dict)
df_top_genre_percentage
# Out:
#                              2001      2002    2003      2006      2009  \
# pop                      0.333333  0.125000  0.1125  0.187500  0.175000
# rock                     0.400000  0.568750  0.4000  0.400000  0.545833
# hip hop                  0.050000       NaN  0.0500  0.050000       NaN
# ska                      0.008333       NaN     NaN       NaN       NaN
# dance                    0.012500       NaN     NaN       NaN       NaN
# metal                    0.025000  0.012500     NaN  0.050000  0.012500
# singer/songwriter        0.020833  0.066667  0.1000  0.083333  0.100000
# jazz                          NaN  0.100000  0.1750  0.150000  0.075000
# northern american music       NaN  0.016667  0.0250       NaN  0.008333
# folk                          NaN  0.035417  0.0750  0.045833  0.041667
# r&b                           NaN  0.012500     NaN  0.025000       NaN
# industrial music              NaN  0.012500     NaN       NaN       NaN
# punk                          NaN       NaN  0.0125  0.008333  0.008333
# electronic                    NaN       NaN     NaN       NaN  0.008333
# ambient                       NaN       NaN     NaN       NaN       NaN
# hardcore [punk]               NaN       NaN     NaN       NaN       NaN
# psychedelia                   NaN       NaN     NaN       NaN       NaN
# downtempo                     NaN       NaN     NaN       NaN       NaN
#
#                              2010      2011      2012      2013      2014  \
# pop                      0.187500  0.162500  0.175000  0.175000  0.175000
# rock                     0.558333  0.583333  0.612500  0.612500  0.612500
# hip hop                       NaN       NaN       NaN       NaN       NaN
# ska                           NaN       NaN       NaN       NaN       NaN
# dance                         NaN       NaN       NaN       NaN       NaN
# metal                    0.012500  0.012500  0.012500  0.012500  0.012500
# singer/songwriter        0.100000  0.100000  0.079167  0.066667  0.066667
# jazz                     0.075000  0.075000  0.075000  0.075000  0.075000
# northern american music  0.008333  0.008333  0.008333  0.008333  0.008333
# folk                     0.041667  0.041667  0.020833  0.033333  0.033333
# r&b                           NaN       NaN       NaN       NaN       NaN
# industrial music              NaN       NaN       NaN       NaN       NaN
# punk                     0.008333  0.008333  0.008333  0.008333  0.008333
# electronic               0.008333  0.008333  0.008333  0.008333  0.008333
# ambient                       NaN       NaN       NaN       NaN       NaN
# hardcore [punk]               NaN       NaN       NaN       NaN       NaN
# psychedelia                   NaN       NaN       NaN       NaN       NaN
# downtempo                     NaN       NaN       NaN       NaN       NaN
#
#                              2015      2016      2017      2018      2020  \
# pop                      0.175000  0.150000  0.150000  0.150000  0.137500
# rock                     0.620833  0.633333  0.645833  0.558333  0.512500
# hip hop                       NaN       NaN       NaN  0.125000  0.150000
# ska                           NaN       NaN       NaN       NaN       NaN
# dance                         NaN       NaN       NaN       NaN       NaN
# metal                    0.037500  0.012500  0.012500  0.012500  0.012500
# singer/songwriter        0.050000  0.050000  0.037500  0.025000  0.037500
# jazz                     0.075000  0.075000  0.075000  0.075000  0.100000
# northern american music       NaN       NaN       NaN       NaN       NaN
# folk                     0.025000  0.025000  0.025000  0.025000  0.025000
# r&b                           NaN       NaN       NaN       NaN       NaN
# industrial music              NaN       NaN       NaN       NaN       NaN
# punk                     0.008333  0.008333  0.008333  0.008333  0.008333
# electronic               0.008333  0.008333  0.008333  0.008333  0.008333
# ambient                       NaN  0.012500  0.012500  0.012500       NaN
# hardcore [punk]               NaN       NaN       NaN       NaN  0.008333
# psychedelia                   NaN       NaN       NaN       NaN       NaN
# downtempo                     NaN       NaN       NaN       NaN       NaN
#
#                              2021      2023
# pop                      0.137500  0.183333
# rock                     0.508333  0.429167
# hip hop                  0.150000  0.150000
# ska                           NaN       NaN
# dance                         NaN       NaN
# metal                    0.012500  0.012500
# singer/songwriter        0.025000  0.012500
# jazz                     0.100000  0.100000
# northern american music       NaN       NaN
# folk                     0.025000  0.025000
# r&b                           NaN  0.025000
# industrial music              NaN       NaN
# punk                          NaN       NaN
# electronic               0.008333  0.020833
# ambient                  0.012500       NaN
# hardcore [punk]          0.008333  0.008333
# psychedelia              0.012500  0.008333
# downtempo                     NaN  0.025000

# %%
sns.set()
plt.figure(dpi = 300)
df_top_genre_percentage = df_top_genre_percentage.sort_values("2001", ascending = False)
ax = df_top_genre_percentage.T.plot(kind="bar", legend = False, stacked=True)
handles, labels = ax.get_legend_handles_labels()
handles = handles[::-1]
labels = labels[::-1]
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.savefig("plots/top_genres.png", dpi = 300, bbox_inches = "tight", pad_inches = 0.5, format = "png")
plt.show()
